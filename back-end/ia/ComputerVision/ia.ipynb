# %%
import os

base_path = "../ComputerVision/dataset"

# criar pastas
os.makedirs(f"{base_path}/valid/images", exist_ok=True)
os.makedirs(f"{base_path}/valid/labels", exist_ok=True)

os.makedirs(f"{base_path}/test/images", exist_ok=True)
os.makedirs(f"{base_path}/test/labels", exist_ok=True)

print("✅ Pastas criadas!")
# Out:
# ✅ Pastas criadas!

# %%
import ultralytics

print(ultralytics.__version__)
# Out:
# 8.4.45

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="../ComputerVision/dataset/data.yaml",
    epochs=50,
    imgsz=640,
)
# Out:
# Ultralytics 8.4.45 🚀 Python-3.14.2 torch-2.11.0 CPU (Apple M1)
# ...

# %%
model.val()

# %%
from IPython.display import Image, display

display(Image(filename='runs/detect/train/results.png'))

# %%
import matplotlib.pyplot as plt

model = YOLO("../ComputerVision/runs/detect/train-2/weights/best.pt")
result = model.predict("../ComputerVision/dataset/train/images/DJI_0124_jpg.rf.RIHaWi8FCRtHJu3tR2ij.jpg", conf=0.5,show=True,save=True)
# Out:
# image 1/1 /Users/u24139/Documents/GitHub/WaterPath_TCC/back-end/ia/ComputerVision/../ComputerVision/dataset/train/images/DJI_0124_jpg.rf.RIHaWi8FCRtHJu3tR2ij.jpg: 480x640 3 Lixos, 63.8ms
# Speed: 8.9ms preprocess, 63.8ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /Users/u24139/Documents/GitHub/WaterPath_TCC/back-end/ia/ComputerVision/runs/detect/predict-7
